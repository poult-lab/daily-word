# %%
with open('./static.txt','r') as f:
    filelist=f.readlines()

print("This the total line of file in txt: ",len(filelist))

new_list=[]

for x in filelist: 
    if x[0]=='#' and x[1]=='#' and x[2]=='#' and x[3]=='#':
        new_list.append(x)

number_counter=[]

for k in new_list:
    print(k)
    number_counter.append(k[-3:-1])
print(number_counter)

total=100
for m in number_counter:
    total=int(m)+total

print(total)
# Out:
# This the total line of file in txt:  37622
# #### 2020/01/03.27
#
# #### 2020/01/07.23
#
# #### 2020/01/08.40
#
# #### 2020/01/09.13
#
# #### 2020/01/11.28
#
# #### 2020/01/14.10
#
# #### 2020/01/15.10
#
# #### 2020/01/16.20
#
# #### 2020/01/17.13
#
# #### 2020/01/18.07
#
# #### 2020/01/19.07
#
# #### 2020/01/21.19
#
# #### 2020/02/13.06
#
# #### 2020/02/14.08
#
# #### 2020/03/06.05
#
# #### 2020/03/25.04
#
# #### 2020/03/26.14
#
# #### 2020/03/27.05
#
# #### 2020/03/28.12
#
# #### 2020/04/02.05
#
# #### 2020/04/03.04
#
# #### 2020/04/04.17
#
# #### 2020/04/05.03
#
# #### 2020/04/06.04
#
# #### 2020/04/08.14
#
# #### 2020/04/09.15
#
# #### 2020/04/12.08
#
# #### 2020/04/14.10
#
# #### 2020/04/15.10
#
# #### 2020/04/16.02
#
# #### 2020/04/18.11
#
# #### 2020/04/19.07
#
# #### 2020/04/23.02
#
# #### 2020/04/24.10
#
# #### 2020/04/26.06
#
# #### 2020/05/07.08
#
# #### 2020/05/08.06
#
# #### 2020/05/09.03
#
# #### 2020/05/15.01
#
# #### 2020/05/17.08
#
# #### 2020/05/18.04
#
# ...

# %%
with open('./static.txt','r') as f:
    filelist=f.readlines()

print("This the total line of file in txt: ",len(filelist))

new_list=[]
one_place=0
ten_place=0

for x in filelist: 
    if x[0]==one_place and x[1]==ten_place:
        
        new_list.append(x)
